# %%
from PIL import Image
import os

DIRECTORIES = {
    "0.5m_with_scale/": "jpg",
    "Depth-Anything-V2/vis_depth/": "png",
    "Depth-Anything-V2/metric_depth/vis_depth/": "png",
}

# %%
def get_file_name(directory):
    file_names = []
    for file in os.listdir(directory):
        name_without_ext = os.path.splitext(file)[0]
        file_names.append(name_without_ext) 
    return file_names
get_file_name('0.5m_with_scale')

# %%
# Get the paths of the images in different directories
def get_images_paths(file_names):
    images_paths = []
    for file_name in file_names:    
        image_paths = []        
        for directory, extension in DIRECTORIES.items():   
            file = f"{file_name}.{extension}"
            image_paths.append(os.path.join(directory, file))
        images_paths.append(image_paths)
    return images_paths

get_images_paths(get_file_name('0.5m_with_scale'))

# %%
from PIL import Image
import os

DIRECTORIES = {
    "0.5m_with_scale/": "jpg",
    "Depth-Anything-V2/vis_depth/": "png",
    "Depth-Anything-V2/metric_depth/vis_depth/": "png",
}

# %%
def get_file_name(directory):
    file_names = []
    for file in os.listdir(directory):
        name_without_ext = os.path.splitext(file)[0]
        file_names.append(name_without_ext) 
    return file_names
get_file_name('0.5m_with_scale')
# Out:
# ['20250502_134648',
#  '20250502_135807',
#  '20250502_144219',
#  '20250502_143358',
#  '20250502_135757',
#  '20250502_135811',
#  '20250613_204703',
#  '20250502_135801',
#  '20250502_144222',
#  '20250502_134659',
#  '20250502_145315',
#  '20250502_135803',
#  '20250502_145328',
#  '20250502_150018',
#  '20250502_140237',
#  '20250502_140223',
#  '20250502_141316',
#  '20250502_142025',
#  '20250502_142031',
#  '20250502_140220',
#  '20250502_140751',
#  '20250502_150026',
#  '20250502_140802',
#  '20250502_150022',
#  '20250502_142037',
#  '20250502_140805',
#  '20250613_203540',
#  '20250502_140226',
#  '20250502_141312',
#  '20250502_142020',
#  '20250613_204223',
#  '20250502_141323',
#  '20250502_140808',
#  '20250502_150012',
#  '20250502_150006',
#  '20250502_141320',
#  '20250502_140758',
#  '20250502_140211',
#  '20250502_142014',
#  '20250502_140213',
#  '20250502_141327',
#  '20250502_134655',
#  '20250502_145325',
#  '20250502_143351',
#  '20250502_134642',
#  '20250502_143347',
#  '20250502_144207',
#  '20250502_143342',
#  '20250502_145336',
#  '20250502_134652',
#  '20250502_145320',
#  '20250502_144228',
#  '20250502_144215',
#  '20250502_143354']

# %%
# Get the paths of the images in different directories
def get_images_paths(file_names):
    images_paths = []
    for file_name in file_names:    
        image_paths = []        
        for directory, extension in DIRECTORIES.items():   
            file = f"{file_name}.{extension}"
            image_paths.append(os.path.join(directory, file))
        images_paths.append(image_paths)
    return images_paths

get_images_paths(get_file_name('0.5m_with_scale'))
# Out:
# [['0.5m_with_scale/20250502_134648.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_134648.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_134648.png'],
#  ['0.5m_with_scale/20250502_135807.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_135807.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_135807.png'],
#  ['0.5m_with_scale/20250502_144219.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_144219.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_144219.png'],
#  ['0.5m_with_scale/20250502_143358.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_143358.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_143358.png'],
#  ['0.5m_with_scale/20250502_135757.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_135757.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_135757.png'],
#  ['0.5m_with_scale/20250502_135811.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_135811.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_135811.png'],
#  ['0.5m_with_scale/20250613_204703.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250613_204703.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250613_204703.png'],
#  ['0.5m_with_scale/20250502_135801.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_135801.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_135801.png'],
#  ['0.5m_with_scale/20250502_144222.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_144222.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_144222.png'],
#  ['0.5m_with_scale/20250502_134659.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_134659.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_134659.png'],
#  ['0.5m_with_scale/20250502_145315.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_145315.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_145315.png'],
#  ['0.5m_with_scale/20250502_135803.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_135803.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_135803.png'],
#  ['0.5m_with_scale/20250502_145328.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_145328.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_145328.png'],
#  ['0.5m_with_scale/20250502_150018.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_150018.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_150018.png'],
#  ['0.5m_with_scale/20250502_140237.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_140237.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_140237.png'],
#  ['0.5m_with_scale/20250502_140223.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_140223.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_140223.png'],
#  ['0.5m_with_scale/20250502_141316.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_141316.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_141316.png'],
#  ['0.5m_with_scale/20250502_142025.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_142025.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_142025.png'],
#  ['0.5m_with_scale/20250502_142031.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_142031.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_142031.png'],
#  ['0.5m_with_scale/20250502_140220.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_140220.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_140220.png'],
#  ['0.5m_with_scale/20250502_140751.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_140751.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_140751.png'],
#  ['0.5m_with_scale/20250502_150026.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_150026.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_150026.png'],
#  ['0.5m_with_scale/20250502_140802.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_140802.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_140802.png'],
#  ['0.5m_with_scale/20250502_150022.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_150022.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_150022.png'],
#  ['0.5m_with_scale/20250502_142037.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_142037.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_142037.png'],
#  ['0.5m_with_scale/20250502_140805.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_140805.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_140805.png'],
#  ['0.5m_with_scale/20250613_203540.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250613_203540.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250613_203540.png'],
#  ['0.5m_with_scale/20250502_140226.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_140226.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_140226.png'],
#  ['0.5m_with_scale/20250502_141312.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_141312.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_141312.png'],
#  ['0.5m_with_scale/20250502_142020.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_142020.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_142020.png'],
#  ['0.5m_with_scale/20250613_204223.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250613_204223.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250613_204223.png'],
#  ['0.5m_with_scale/20250502_141323.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_141323.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_141323.png'],
#  ['0.5m_with_scale/20250502_140808.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_140808.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_140808.png'],
#  ['0.5m_with_scale/20250502_150012.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_150012.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_150012.png'],
#  ['0.5m_with_scale/20250502_150006.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_150006.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_150006.png'],
#  ['0.5m_with_scale/20250502_141320.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_141320.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_141320.png'],
#  ['0.5m_with_scale/20250502_140758.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_140758.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_140758.png'],
#  ['0.5m_with_scale/20250502_140211.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_140211.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_140211.png'],
#  ['0.5m_with_scale/20250502_142014.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_142014.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_142014.png'],
#  ['0.5m_with_scale/20250502_140213.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_140213.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_140213.png'],
#  ['0.5m_with_scale/20250502_141327.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_141327.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_141327.png'],
#  ['0.5m_with_scale/20250502_134655.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_134655.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_134655.png'],
#  ['0.5m_with_scale/20250502_145325.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_145325.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_145325.png'],
#  ['0.5m_with_scale/20250502_143351.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_143351.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_143351.png'],
#  ['0.5m_with_scale/20250502_134642.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_134642.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_134642.png'],
#  ['0.5m_with_scale/20250502_143347.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_143347.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_143347.png'],
#  ['0.5m_with_scale/20250502_144207.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_144207.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_144207.png'],
#  ['0.5m_with_scale/20250502_143342.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_143342.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_143342.png'],
#  ['0.5m_with_scale/20250502_145336.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_145336.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_145336.png'],
#  ['0.5m_with_scale/20250502_134652.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_134652.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_134652.png'],
#  ['0.5m_with_scale/20250502_145320.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_145320.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_145320.png'],
#  ['0.5m_with_scale/20250502_144228.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_144228.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_144228.png'],
#  ['0.5m_with_scale/20250502_144215.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_144215.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_144215.png'],
#  ['0.5m_with_scale/20250502_143354.jpg',
#   'Depth-Anything-V2/vits_vis_depth/20250502_143354.png',
#   'Depth-Anything-V2/metric_depth/vits_vis_depth/20250502_143354.png']]

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 8
#       6         combined_image.save(f"combined_image_{i}.png")
#       7         print(f"Saved combined image {i} as combined_image_{i}.png")
# ----> 8 main()
#
# Cell In[21], line 5, in main()
#       3 images_paths = get_images_paths(file_names)
#       4 for i, paths in enumerate(images_paths):
# ----> 5     combined_image = combine_images(paths)
#       6     combined_image.save(f"combined_image_{i}.png")
#       7     print(f"Saved combined image {i} as combined_image_{i}.png")
#
# Cell In[12], line 2, in combine_images(image_paths)
#       1 def combine_images(image_paths):
# ----> 2     images = [Image.open(path) for path in image_paths]
#       3     widths, heights = zip(*(i.size for i in images))
#       5     total_width = sum(widths)
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/earnesthsiao/Documents/Lab/Depth Models/Depth-Anything-V2/vis_depth/20250502_134648.jpg'
